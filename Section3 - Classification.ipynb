# %% [markdown]
# ## 1. Making classification data

# %%
from sklearn.datasets import make_circles

n_samples = 1000

X,y = make_circles(n_samples)

# %%
X[:5] , y[:5]
# Out:
# (array([[-0.21836155,  0.76962214],
#         [-0.13779029, -0.99046143],
#         [ 0.51443953,  0.85752666],
#         [-0.05024432, -0.99873696],
#         [-0.6034011 , -0.5252686 ]]),
#  array([1, 0, 0, 0, 1]))

# %%
import pandas as pd
circles = pd.DataFrame({'X1' : X[: , 0],
                        'X2' : X[: , 1],
                        'label' : y})
circles.head(10)
# Out:
#          X1        X2  label
# 0 -0.218362  0.769622      1
# 1 -0.137790 -0.990461      0
# 2  0.514440  0.857527      0
# 3 -0.050244 -0.998737      0
# 4 -0.603401 -0.525269      1
# 5 -0.986686  0.162637      0
# 6  0.770513  0.637424      0
# 7  0.478324 -0.641254      1
# 8 -0.647056  0.762443      0
# 9  0.893841  0.448383      0

# %%
import matplotlib.pyplot as plt
plt.scatter(X[: , 0] , X[: , 1] , color='red')

# %%
### Check the input and output shapes

X.shape , y.shape
# Out:
# ((1000, 2), (1000,))

# %%
X
# Out:
# array([[-0.21836155,  0.76962214],
#        [-0.13779029, -0.99046143],
#        [ 0.51443953,  0.85752666],
#        ...,
#        [ 0.67002243,  0.43711548],
#        [-0.75439243, -0.26625564],
#        [-0.50215309, -0.62276984]])

# %% [markdown]
# ## 2. Making train and test split

# %%
import torch
X = torch.from_numpy(X).type(torch.float)
y = torch.from_numpy(y).type(torch.float)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.25 , random_state=42)

# %%
# Out:
# 750
